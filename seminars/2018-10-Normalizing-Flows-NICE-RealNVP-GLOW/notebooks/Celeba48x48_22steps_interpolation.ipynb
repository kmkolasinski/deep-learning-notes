# %% [markdown]
# # Normalizing flows:  re-implementation of the Glow paper
#
# Test latent space interpolations on trained model. The model should be first trained with
# `Celeba48x48_22steps` notebooks. Here we just load weights and do some experiments with latent space variables.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import numpy as np
import tensorflow as tf
from scipy.stats import norm
import matplotlib.pyplot as plt

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import utils
import nets
import flow_layers as fl

# %%
tf.set_random_seed(0)
sess = tf.InteractiveSession()

# %% [markdown]
# ## Import dataset

# %%
batch_size = 8
image_size = 48
x_valid_samples = utils.create_tfrecord_dataset_iterator(
    "datasets/celeba/celeba_valid.tfrecords", batch_size=batch_size, image_size=image_size
)

# %% [markdown]
# ### Check shapes (initial call will take a while)

# %%
x_exampled = x_valid_samples.eval()

# %%
plt.imshow(utils.plot_grid(x_valid_samples).eval())

# %% [markdown]
# ## Build Flow
#
# This should be exactly the same as trained model, otherwise loading weights will fail.

# %%
nn_template_fn = nets.OpenAITemplate(
    width=148
)

# %%
x_image_ph = tf.placeholder(tf.float32, [1, image_size, image_size, 3])

# %%
layers, actnorm_layers = nets.create_simple_flow(
    num_steps=22, 
    num_scales=3, 
    template_fn=nn_template_fn
)

flow = fl.InputLayer(x_image_ph)
model_flow = fl.ChainLayer(layers)
output_flow = model_flow(flow, forward=True)
# Out:
# QuantizeImage/Forward/                  : x=[1, 48, 48, 3]	z=[None]	logdet=[1]
# SqueezingLayer/Forward/Scale1           : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step1                : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step2                : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step3                : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step4                : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step5                : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step6                : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step7                : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step8                : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step9                : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step10               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step11               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step12               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step13               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step14               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step15               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step16               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step17               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step18               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step19               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step20               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step21               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Step22               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# ChainLayer/Forward/Scale1               : x=[1, 24, 24, 12]	z=[None]	logdet=[1]
# FactorOutLayer/Forward/Scale1           : x=[1, 24, 24, 6]	z=[1, 24, 24, 6]	logdet=[1]
# SqueezingLayer/Forward/Scale2           : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step1                : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step2                : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step3                : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step4                : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step5                : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step6                : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step7                : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step8                : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step9                : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step10               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step11               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step12               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step13               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step14               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step15               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step16               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step17               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step18               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step19               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step20               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step21               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Step22               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Forward/Scale2               : x=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# FactorOutLayer/Forward/Scale2           : x=[1, 12, 12, 12]	z=[1, 12, 12, 36]	logdet=[1]
# SqueezingLayer/Forward/Scale3           : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step1                : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step2                : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step3                : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step4                : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step5                : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step6                : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step7                : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step8                : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step9                : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step10               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step11               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step12               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step13               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step14               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step15               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step16               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step17               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step18               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step19               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step20               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step21               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Forward/               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Forward/              : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Forward/                   : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Forward/         : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Forward/            : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Step22               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Forward/Scale3               : x=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# FactorOutLayer/Forward/Scale3           : x=[1, 6, 6, 24]	z=[1, 6, 6, 168]	logdet=[1]
# ChainLayer/Forward/                     : x=[1, 6, 6, 24]	z=[1, 6, 6, 168]	logdet=[1]

# %% [markdown]
# ## Prepare output tensors

# %%
y, logdet, z = output_flow
output_flow
# Out:
# (<tf.Tensor 'ChainLayer_1/outputs/x:0' shape=(1, 6, 6, 24) dtype=float32>,
#  <tf.Tensor 'ChainLayer_1/outputs/lodget:0' shape=(1,) dtype=float32>,
#  <tf.Tensor 'ChainLayer_1/outputs/z:0' shape=(1, 6, 6, 168) dtype=float32>)

# %%
tfd = tf.contrib.distributions

# %% [markdown]
# ## Sampling from model
#
# It seems that the best results are obtained when the temperature of the distribution of the Z variable is close
# or equal to zero.

# %%
y_prior_ph = tf.placeholder(tf.float32, y.shape.as_list())
z_prior_ph = tf.placeholder(tf.float32, z.shape.as_list())

logdet_pior_tmp = tf.zeros_like(logdet)

# %%
inverse_flow_prim = y_prior_ph, logdet_pior_tmp, z_prior_ph
sampled_flow_prim = model_flow(inverse_flow_prim, forward=False)
# Out:
# FactorOutLayer/Backward/Scale3          : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step22              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step21              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step20              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step19              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step18              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step17              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step16              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step15              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step14              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step13              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step12              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step11              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step10              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step9               : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step8               : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step7               : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step6               : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step5               : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step4               : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step3               : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step2               : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Step1               : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# ChainLayer/Backward/Scale3              : y=[1, 6, 6, 48]	z=[1, 6, 6, 144]	logdet=[1]
# SqueezingLayer/Backward/Scale3          : y=[1, 12, 12, 12]	z=[1, 12, 12, 36]	logdet=[1]
# FactorOutLayer/Backward/Scale2          : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step22              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step21              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step20              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step19              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step18              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step17              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step16              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step15              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step14              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step13              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step12              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step11              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step10              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step9               : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step8               : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step7               : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step6               : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step5               : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step4               : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step3               : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step2               : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Step1               : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# ChainLayer/Backward/Scale2              : y=[1, 12, 12, 24]	z=[1, 12, 12, 24]	logdet=[1]
# SqueezingLayer/Backward/Scale2          : y=[1, 24, 24, 6]	z=[1, 24, 24, 6]	logdet=[1]
# FactorOutLayer/Backward/Scale1          : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step22              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step21              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step20              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step19              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step18              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step17              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step16              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step15              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step14              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step13              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step12              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step11              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step10              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step9               : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step8               : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step7               : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step6               : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step5               : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step4               : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step3               : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step2               : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# AffineCouplingLayer/Backward/           : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# InvertibleConv1x1Layer/Backward/        : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormScaleLayer/Backward/             : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormBiasLayer/Backward/              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ActnormLayer/Backward/                  : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Step1               : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# ChainLayer/Backward/Scale1              : y=[1, 24, 24, 12]	z=[1, 24, 24, 0]	logdet=[1]
# SqueezingLayer/Backward/Scale1          : y=[1, 48, 48, 3]	z=[1, 48, 48, 0]	logdet=[1]
# QuantizeImage/Backward/                 : y=[1, 48, 48, 3]	z=[1, 48, 48, 0]	logdet=[1]
# ChainLayer/Backward/                    : y=[1, 48, 48, 3]	z=[1, 48, 48, 0]	logdet=[1]

# %%
x_flow_sampled_prim, _, _ = sampled_flow_prim

# %% [markdown]
# # Load saved model from checkpoint

# %%
saver = tf.train.Saver()
saver.restore(sess, "./experiments/celeba48x48_22steps.ckpt")
# Out:
# INFO:tensorflow:Restoring parameters from ./experiments/celeba48x48_22steps.ckpt

# %% [markdown]
# ### Effect of the temperature on the Z latent variable

# %%
y_shape = y_prior_ph.shape.as_list()
z_shape = z_prior_ph.shape.as_list()

# %%
noise_y = np.random.randn(*y_shape)
noise_z = np.random.randn(*z_shape)
images = []
for w in np.linspace(0, 1.5, 16):
    sampled_image = x_flow_sampled_prim.eval({
        y_prior_ph: w*noise_y, 
        z_prior_ph: 0.3*noise_z
    })[0]
    images.append(sampled_image)

images = np.array(images)
utils.plot_4x4_grid(images, images.shape[1:], figsize=(10, 10))

# %% [markdown]
# # Interpolation

# %%
x_example_images = x_valid_samples.eval()
image_a = x_example_images[:1, ...]
image_b = x_example_images[1:2, ...]
plt.subplot(121)
plt.imshow(image_a[0])
plt.subplot(122)
plt.imshow(image_b[0])

# %%
latent_y_a, _, latent_z_a = sess.run([y, logdet, z], feed_dict={x_image_ph: image_a})
latent_y_b, _, latent_z_b = sess.run([y, logdet, z], feed_dict={x_image_ph: image_b})

# %%
images = []
for w in np.linspace(0, 1.0, 16):
    sampled_image = x_flow_sampled_prim.eval({
        y_prior_ph: (1 - w) * latent_y_a + w * latent_y_b, 
        z_prior_ph: (1 - w) * latent_z_a + w * latent_z_b
    })[0]
    images.append(sampled_image)

images = np.array(images)
utils.plot_4x4_grid(images, images.shape[1:], figsize=(10, 10))
